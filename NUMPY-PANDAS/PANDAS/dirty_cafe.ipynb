# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("E:\\DATA SCIENCE\\NUMPY-PANDAS\\DATASETS\\dirty_cafe_sales.csv")

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.rename(columns={'Price Per Unit':'Price_Per_Unit','Total Spent':'Total_Spent','Transaction Date':'Transaction_Date','Payment Method':'Payment_Method','Transaction ID':'Transaction_ID'},inplace=True)

# %%
df
# Out:
#      Transaction_ID      Item Quantity Price_Per_Unit Total_Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment_Method  Location Transaction_Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df1=df.drop(columns=['Transaction_ID','Payment_Method','Location','Transaction_Date'])

# %%
df1
# Out:
#           Item Quantity Price_Per_Unit Total_Spent
# 0       Coffee        2            2.0         4.0
# 1         Cake        4            3.0        12.0
# 2       Cookie        4            1.0       ERROR
# 3        Salad        2            5.0        10.0
# 4       Coffee        2            2.0         4.0
# ...        ...      ...            ...         ...
# 9995    Coffee        2            2.0         4.0
# 9996       NaN        3            NaN         3.0
# 9997    Coffee        4            2.0         8.0
# 9998    Cookie        3            NaN         3.0
# 9999  Sandwich        3            4.0        12.0
#
# [10000 rows x 4 columns]

# %%
df1.dtypes
# Out:
# Item              object
# Quantity          object
# Price_Per_Unit    object
# Total_Spent       object
# dtype: object

# %%
df1.Quantity.unique()
# Out:
# array(['2', '4', '5', '3', '1', 'ERROR', 'UNKNOWN', nan], dtype=object)

# %%
df1.Item.unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', nan, 'ERROR', 'Juice', 'Tea'], dtype=object)

# %%
df1.head(9)
# Out:
#        Item Quantity Price_Per_Unit Total_Spent
# 0    Coffee        2            2.0         4.0
# 1      Cake        4            3.0        12.0
# 2    Cookie        4            1.0       ERROR
# 3     Salad        2            5.0        10.0
# 4    Coffee        2            2.0         4.0
# 5  Smoothie        5            4.0        20.0
# 6   UNKNOWN        3            3.0         9.0
# 7  Sandwich        4            4.0        16.0
# 8       NaN        5            3.0        15.0

# %%
df1['Price_Per_Unit'].replace(['UNKNOWN','ERROR'], np.nan, inplace=True)

# %%
df1.Price_Per_Unit.unique()
# Out:
# array(['2.0', '3.0', '1.0', '5.0', '4.0', '1.5', nan], dtype=object)

# %%
df1['Quantity'].replace(['UNKNOWN','ERROR'], np.nan, inplace=True)

# %%
df1.Quantity.unique()
# Out:
# array(['2', '4', '5', '3', '1', nan], dtype=object)

# %%
df1.Total_Spent.unique()
# Out:
# array(['4.0', '12.0', 'ERROR', '10.0', '20.0', '9.0', '16.0', '15.0',
#        '25.0', '8.0', '5.0', '3.0', '6.0', nan, 'UNKNOWN', '2.0', '1.0',
#        '7.5', '4.5', '1.5'], dtype=object)

# %%
df1['Total_Spent'].replace(['UNKNOWN','ERROR'], np.nan, inplace=True)

# %%
df1.Total_Spent.unique()
# Out:
# array(['4.0', '12.0', nan, '10.0', '20.0', '9.0', '16.0', '15.0', '25.0',
#        '8.0', '5.0', '3.0', '6.0', '2.0', '1.0', '7.5', '4.5', '1.5'],
#       dtype=object)

# %%
df1
# Out:
#           Item Quantity Price_Per_Unit Total_Spent
# 0       Coffee        2            2.0         4.0
# 1         Cake        4            3.0        12.0
# 2       Cookie        4            1.0         NaN
# 3        Salad        2            5.0        10.0
# 4       Coffee        2            2.0         4.0
# ...        ...      ...            ...         ...
# 9995    Coffee        2            2.0         4.0
# 9996       NaN        3            NaN         3.0
# 9997    Coffee        4            2.0         8.0
# 9998    Cookie        3            NaN         3.0
# 9999  Sandwich        3            4.0        12.0
#
# [10000 rows x 4 columns]

# %%
df1.dtypes
# Out:
# Item              object
# Quantity          object
# Price_Per_Unit    object
# Total_Spent       object
# dtype: object

# %%
def datatype(x):
    return float(x)
a='10'
datatype(a)
# Out:
# 10.0

# %%
df1['Price_Per_Unit']=df1.Price_Per_Unit.apply(datatype)

# %%
df1.Price_Per_Unit.unique()
# Out:
# array([2. , 3. , 1. , 5. , 4. , 1.5, nan])

# %%
df1['Quantity']=df1.Quantity.apply(datatype)

# %%
df1.Quantity.unique()
# Out:
# array([ 2.,  4.,  5.,  3.,  1., nan])

# %%
df1['Total_Spent']=df1.Total_Spent.apply(datatype)

# %%
df1.Total_Spent.unique()
# Out:
# array([ 4. , 12. ,  nan, 10. , 20. ,  9. , 16. , 15. , 25. ,  8. ,  5. ,
#         3. ,  6. ,  2. ,  1. ,  7.5,  4.5,  1.5])

# %%
df1.dtypes
# Out:
# Item               object
# Quantity          float64
# Price_Per_Unit    float64
# Total_Spent       float64
# dtype: object

# %%
df1['new_price']=df1['Total_Spent']/df1['Quantity']

# %%
df1['new_price']
# Out:
# 0       2.0
# 1       3.0
# 2       NaN
# 3       5.0
# 4       2.0
#        ...
# 9995    2.0
# 9996    1.0
# 9997    2.0
# 9998    1.0
# 9999    4.0
# Name: new_price, Length: 10000, dtype: float64

# %%
df1
# Out:
#           Item  Quantity  Price_Per_Unit  Total_Spent  new_price
# 0       Coffee       2.0             2.0          4.0        2.0
# 1         Cake       4.0             3.0         12.0        3.0
# 2       Cookie       4.0             1.0          NaN        NaN
# 3        Salad       2.0             5.0         10.0        5.0
# 4       Coffee       2.0             2.0          4.0        2.0
# ...        ...       ...             ...          ...        ...
# 9995    Coffee       2.0             2.0          4.0        2.0
# 9996       NaN       3.0             NaN          3.0        1.0
# 9997    Coffee       4.0             2.0          8.0        2.0
# 9998    Cookie       3.0             NaN          3.0        1.0
# 9999  Sandwich       3.0             4.0         12.0        4.0
#
# [10000 rows x 5 columns]

# %%
df1['new_price'] = df1['new_price'].fillna(df1['Price_Per_Unit'])

# %%
df1['new_price']
# Out:
# 0       2.0
# 1       3.0
# 2       1.0
# 3       5.0
# 4       2.0
#        ...
# 9995    2.0
# 9996    1.0
# 9997    2.0
# 9998    1.0
# 9999    4.0
# Name: new_price, Length: 10000, dtype: float64

# %%
df1['new_quantity']=df1['Total_Spent']/df1['new_price']

# %%
df1
# Out:
#           Item  Quantity  Price_Per_Unit  Total_Spent  new_price  new_quantity
# 0       Coffee       2.0             2.0          4.0        2.0           2.0
# 1         Cake       4.0             3.0         12.0        3.0           4.0
# 2       Cookie       4.0             1.0          NaN        1.0           NaN
# 3        Salad       2.0             5.0         10.0        5.0           2.0
# 4       Coffee       2.0             2.0          4.0        2.0           2.0
# ...        ...       ...             ...          ...        ...           ...
# 9995    Coffee       2.0             2.0          4.0        2.0           2.0
# 9996       NaN       3.0             NaN          3.0        1.0           3.0
# 9997    Coffee       4.0             2.0          8.0        2.0           4.0
# 9998    Cookie       3.0             NaN          3.0        1.0           3.0
# 9999  Sandwich       3.0             4.0         12.0        4.0           3.0
#
# ...

# %%
df1['new_quantity']
# Out:
# 0       2.0
# 1       4.0
# 2       NaN
# 3       2.0
# 4       2.0
#        ...
# 9995    2.0
# 9996    3.0
# 9997    4.0
# 9998    3.0
# 9999    3.0
# Name: new_quantity, Length: 10000, dtype: float64

# %%
df1['new_quantity']=df1['new_quantity'].fillna(df1['Quantity'])

# %%
df1['new_total']=df1['new_price']*df1['new_quantity']

# %%
df1['new_total']=df1['new_total'].fillna(df1['Total_Spent'])

# %%
df2=df1.drop(columns=['Quantity','Price_Per_Unit','Total_Spent'])

# %%
df2
# Out:
#           Item  new_price  new_quantity  new_total
# 0       Coffee        2.0           2.0        4.0
# 1         Cake        3.0           4.0       12.0
# 2       Cookie        1.0           4.0        4.0
# 3        Salad        5.0           2.0       10.0
# 4       Coffee        2.0           2.0        4.0
# ...        ...        ...           ...        ...
# 9995    Coffee        2.0           2.0        4.0
# 9996       NaN        1.0           3.0        3.0
# 9997    Coffee        2.0           4.0        8.0
# 9998    Cookie        1.0           3.0        3.0
# 9999  Sandwich        4.0           3.0       12.0
#
# [10000 rows x 4 columns]

# %%
df2.isnull().sum()
# Out:
# Item            333
# new_price        38
# new_quantity     38
# new_total        40
# dtype: int64

# %%
price_1=df2.new_price==1

# %%
price_1
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: new_price, Length: 10000, dtype: bool

# %%
cookie=df2.loc[price_1,['Item','new_price','new_quantity','new_total']]

# %%
cookie.shape
# Out:
# (1207, 4)

# %%
cookie.isnull().sum()
# Out:
# Item            40
# new_price        0
# new_quantity     2
# new_total        2
# dtype: int64

# %%
cookie.Item.unique()
# Out:
# array(['Cookie', 'UNKNOWN', nan, 'ERROR'], dtype=object)

# %%
cookie['Item'].replace(['UNKNOWN','ERROR',np.nan],'Cookie',inplace=True)

# %%
cookie.Item.unique()
# Out:
# array(['Cookie'], dtype=object)

# %%
cookie=cookie.dropna(subset=['new_total', 'new_quantity'],how='all')

# %%
cookie.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    0
# new_total       0
# dtype: int64

# %%
cookie.shape
# Out:
# (1205, 4)

# %%
price_15=df2.new_price==1.5

# %%
tea=df2.loc[price_15,['Item','new_price','new_quantity','new_total']]

# %%
tea.shape
# Out:
# (1200, 4)

# %%
tea.Item.unique()
# Out:
# array(['ERROR', 'Tea', nan, 'UNKNOWN'], dtype=object)

# %%
tea['Item'].replace(['UNKNOWN','ERROR',np.nan],'Tea',inplace=True)

# %%
tea.Item.unique()
# Out:
# array(['Tea'], dtype=object)

# %%
tea.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    1
# new_total       1
# dtype: int64

# %%
tea=tea.dropna(subset=['new_quantity','new_total'],how='all')

# %%
tea.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    0
# new_total       0
# dtype: int64

# %%
tea.shape
# Out:
# (1199, 4)

# %%
price_2=df2.new_price==2

# %%
price_2=df2.loc[price_2,['Item','new_price','new_quantity','new_total']]

# %%
price_2.Item.unique()
# Out:
# array(['Coffee', nan, 'ERROR', 'UNKNOWN'], dtype=object)

# %%
price_2.shape
# Out:
# (1289, 4)

# %%
price_2['Item'].replace(['ERROR','UNKNOWN',np.nan],'Coffee',inplace=True)

# %%
price_2.Item.unique()
# Out:
# array(['Coffee'], dtype=object)

# %%
price_2.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    5
# new_total       5
# dtype: int64

# %%
price_2=price_2.dropna(subset=['new_quantity','new_total'],how='all')

# %%
price_2.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    0
# new_total       0
# dtype: int64

# %%
price_3=df2.new_price==3

# %%
price_3=df2.loc[price_3,['Item','new_price','new_quantity','new_total']]

# %%
price_3.shape
# Out:
# (2552, 4)

# %%
price_3.Item.unique()
# Out:
# array(['Cake', 'UNKNOWN', nan, 'Juice', 'ERROR'], dtype=object)

# %%
price_3['Item'].replace(['UNKNOWN','ERROR',np.nan],'Juice',inplace=True)

# %%
price_3.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    4
# new_total       4
# dtype: int64

# %%
price_3=price_3.dropna(subset=['new_quantity','new_total'],how='all')

# %%
price_3.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    0
# new_total       0
# dtype: int64

# %%
price_3.shape
# Out:
# (2548, 4)

# %%
price_4=df2.new_price==4

# %%
price_4=df2.loc[price_4,['Item','new_price','new_quantity','new_total']]

# %%
price_4.shape
# Out:
# (2444, 4)

# %%
price_4.Item.unique()
# Out:
# array(['Smoothie', 'Sandwich', nan, 'UNKNOWN', 'ERROR'], dtype=object)

# %%
price_4['Item'].replace(['UNKNOWN','ERROR',np.nan],'Sandwich',inplace=True)

# %%
price_4.Item.unique()
# Out:
# array(['Smoothie', 'Sandwich'], dtype=object)

# %%
price_4.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    6
# new_total       6
# dtype: int64

# %%
price_4=price_4.dropna(subset=['new_quantity','new_total'],how='all')

# %%
price_4.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    0
# new_total       0
# dtype: int64

# %%
price_5=df2.new_price==5

# %%
price_5=df2.loc[price_5,['Item','new_price','new_quantity','new_total']]

# %%
price_5.shape
# Out:
# (1270, 4)

# %%
price_5.Item.unique()
# Out:
# array(['Salad', 'UNKNOWN', 'ERROR', nan], dtype=object)

# %%
price_5['Item'].replace(['UNKNOWN','ERROR',np.nan],'Salad',inplace=True)

# %%
price_5.Item.unique()
# Out:
# array(['Salad'], dtype=object)

# %%
price_5.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    2
# new_total       2
# dtype: int64

# %%
price_5=price_5.dropna(subset=['new_quantity','new_total'],how='all')

# %%
price_5.shape
# Out:
# (1268, 4)

# %%
price_5.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    0
# new_total       0
# dtype: int64

# %%
price_null=df2.new_price.isnull()==True

# %%
price_null=df2.loc[price_null,['Item','new_price','new_quantity','new_total']]

# %%
price_null
# Out:
#           Item  new_price  new_quantity  new_total
# 65    Sandwich        NaN           3.0        NaN
# 629       Cake        NaN           NaN       12.0
# 912   Sandwich        NaN           NaN       20.0
# 1008       Tea        NaN           NaN        3.0
# 1436       Tea        NaN           NaN        6.0
# 1482  Smoothie        NaN           NaN       16.0
# 1674       Tea        NaN           2.0        NaN
# 1761       NaN        NaN           4.0        NaN
# 2229  Sandwich        NaN           2.0        NaN
# 2289   UNKNOWN        NaN           4.0        NaN
# 2330     Salad        NaN           NaN        5.0
# 2585       Tea        NaN           3.0        NaN
# 3162      Cake        NaN           3.0        NaN
# 3598  Smoothie        NaN           1.0        NaN
# 3635    Cookie        NaN           NaN        1.0
# 3673  Smoothie        NaN           2.0        NaN
# 3779   UNKNOWN        NaN           NaN       25.0
# ...

# %%
price_null['Item'].replace(['ERROR','UNKNOWN'],np.nan,inplace=True)

# %%
price_null.dropna(subset=['Item'],inplace=True)

# %%
price_null.shape
# Out:
# (32, 4)

# %%
def price(x):
    if x=='Cookie':
        return 1
    elif x=='Tea':
        return 1.5
    elif x=='Coffee':
        return 2
    elif x=='Cake':
        return 3
    elif x=='Juice':
        return 3
    elif x=='Smoothie':
        return 4
    elif x=='Sandwich':
        return 4
    else:
        return 5
a='Cake'
b='vignesh'
price(a)
# Out:
# 3

# %%
price_null['new_price']=price_null.Item.apply(price)

# %%
price_null.shape
# Out:
# (32, 4)

# %%
price_null['new']=price_null['new_total']/price_null['new_price']

# %%
price_null
# Out:
#           Item  new_price  new_quantity  new_total  new
# 65    Sandwich        4.0           3.0        NaN  NaN
# 629       Cake        3.0           NaN       12.0  4.0
# 912   Sandwich        4.0           NaN       20.0  5.0
# 1008       Tea        1.5           NaN        3.0  2.0
# 1436       Tea        1.5           NaN        6.0  4.0
# 1482  Smoothie        4.0           NaN       16.0  4.0
# 1674       Tea        1.5           2.0        NaN  NaN
# 2229  Sandwich        4.0           2.0        NaN  NaN
# 2330     Salad        5.0           NaN        5.0  1.0
# 2585       Tea        1.5           3.0        NaN  NaN
# 3162      Cake        3.0           3.0        NaN  NaN
# 3598  Smoothie        4.0           1.0        NaN  NaN
# 3635    Cookie        1.0           NaN        1.0  1.0
# 3673  Smoothie        4.0           2.0        NaN  NaN
# 4021    Cookie        1.0           2.0        NaN  NaN
# 5639       Tea        1.5           NaN        6.0  4.0
# ...

# %%
price_null['new_quantity']=price_null['new'].fillna(price_null['new_quantity'])

# %%
price_null['new_total']=price_null['new_price']*price_null['new_quantity']

# %%
price_null.drop('new',axis=1,inplace=True)

# %%
price_null
# Out:
#           Item  new_price  new_quantity  new_total
# 65    Sandwich        4.0           3.0       12.0
# 629       Cake        3.0           4.0       12.0
# 912   Sandwich        4.0           5.0       20.0
# 1008       Tea        1.5           2.0        3.0
# 1436       Tea        1.5           4.0        6.0
# 1482  Smoothie        4.0           4.0       16.0
# 1674       Tea        1.5           2.0        3.0
# 2229  Sandwich        4.0           2.0        8.0
# 2330     Salad        5.0           1.0        5.0
# 2585       Tea        1.5           3.0        4.5
# 3162      Cake        3.0           3.0        9.0
# 3598  Smoothie        4.0           1.0        4.0
# 3635    Cookie        1.0           1.0        1.0
# 3673  Smoothie        4.0           2.0        8.0
# 4021    Cookie        1.0           2.0        2.0
# 5639       Tea        1.5           4.0        6.0
# 5845  Smoothie        4.0           2.0        8.0
# ...

# %%
price_null.dtypes
# Out:
# Item             object
# new_price       float64
# new_quantity    float64
# new_total       float64
# dtype: object

# %%
final_result=cookie._append([tea,price_2,price_3,price_4,price_5,price_null],ignore_index=True)

# %%
final_result
# Out:
#         Item  new_price  new_quantity  new_total
# 0     Cookie        1.0           4.0        4.0
# 1     Cookie        1.0           5.0        5.0
# 2     Cookie        1.0           5.0        5.0
# 3     Cookie        1.0           2.0        2.0
# 4     Cookie        1.0           5.0        5.0
# ...      ...        ...           ...        ...
# 9969    Cake        3.0           1.0        3.0
# 9970     Tea        1.5           5.0        7.5
# 9971     Tea        1.5           1.0        1.5
# 9972    Cake        3.0           1.0        3.0
# 9973   Juice        3.0           2.0        6.0
#
# [9974 rows x 4 columns]

# %%
final_result.shape
# Out:
# (9974, 4)

# %%
final_result.isnull().sum()
# Out:
# Item            0
# new_price       0
# new_quantity    0
# new_total       0
# dtype: int64

# %%
final_result.sample(10)
# Out:
#           Item  new_price  new_quantity  new_total
# 6086      Cake        3.0           3.0        9.0
# 2483    Coffee        2.0           2.0        4.0
# 9508     Salad        5.0           2.0       10.0
# 1273       Tea        1.5           2.0        3.0
# 6966  Smoothie        4.0           1.0        4.0
# 8251  Smoothie        4.0           3.0       12.0
# 2291       Tea        1.5           4.0        6.0
# 4949     Juice        3.0           3.0        9.0
# 9608     Salad        5.0           2.0       10.0
# 8770     Salad        5.0           3.0       15.0

# %%
final_result.to_csv("C:\\Users\\vignesh\\OneDrive\\Desktop\\Cafe in pandas\\Cafe_no_null.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 final_result.to_csv("C:\\Users\\vignesh\\OneDrive\\Desktop\\Cafe in pandas\\Cafe_no_null.csv")
#
# File ~\.conda\envs\tf_env\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
