# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('D:\PYTHON CODINGS\PANDAS\STACK OVERFLOW SURVEY SET\stack-overflow-developer-survey-2019\survey_results_public.csv')
schema = pd.read_csv('D:\PYTHON CODINGS\PANDAS\STACK OVERFLOW SURVEY SET\stack-overflow-developer-survey-2019\survey_results_schema.csv')

# %%
df.sample(2)

# %%
df[df.ConvertedComp > 25000]['Hobbyist']

# %%
filters = df.ConvertedComp > 90000
above_90000 = df[filters]

# %%
above_90000.shape

# %%
df[filters]['MainBranch']

# %%
df.loc[filters,['MainBranch','Hobbyist']]

# %%
df.loc[filters]

# %%
df.loc[filters,['Hobbyist','MainBranch']]

# %%
schema.loc[1,'QuestionText']

# %%
schema.iloc[1]

# %%
df.Country.value_counts()

# %%
countries = ['India','Germany','Canada','Tonga']
filter = df['Country'].isin(countries)

# %%
df.loc[filter,['Country','LanguageWorkedWith']]

# %%
a = df['LanguageWorkedWith'].str.contains('Python',na = False)

# %%
df.loc[a,['Hobbyist','Country','LanguageWorkedWith']]

# %%
b = (df.Country == 'India') & (df.ConvertedComp > 90000)

# %%
df.loc[b,['MainBranch','Hobbyist']]

# %%
df.loc[88065,'MainBranch']
