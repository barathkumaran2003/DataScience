# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
dt = {
    'Movie': ['Shyam Singha Roy','Jersey','Vaaranam Aayiram','Minnale','Virumaandi','Bombay','Missing'
              ,'Theri','Coolie','Shiddat','KGF','Amaran'],
    'Hero': ['Naani',None,'Suriya','Madhavan','Missing','NA',np.nan,'Vijay','Rajini'
             ,'Sunny Kaushal','Yash','SK'],
    'Heroine':['Sai Pallavi','NA',np.nan,'Reema Sen','Missing','Manisha koriala','NA','Samantha','NA',
              'Radhika Madan','Srinidhi Shetty','Sai Pallavi'],
    'Rating':['NA',10,9.5,np.nan,'Missing',8,None,9.9,3.9,10,9.5,np.nan]
    ,'Box_Office_in_CRORE':[60,90,50,39,20,10,'Missing',100,90,100,150,120]
}

# %%
df = pd.DataFrame(dt)

# %%
df

# %%
df.replace({'NA':np.nan},inplace = True)

# %%
df.replace({'Missing':np.nan},inplace = True)

# %%
df

# %%
df.dropna()
# DROP ROW HAVING NULL VALUES

# %%
df.dropna(axis = 1)

# %%
df.dropna(how = 'all',axis = 0)

# %%
df.dropna(axis = 0,how = 'any',subset = ['Hero'])

# %%
df.dropna(axis = 0,how = 'any',subset = ['Hero','Heroine'])

# %%
df.dropna(axis = 0,how = 'all',subset = ['Hero','Heroine'])

# %%
df.fillna(0)

# %%
df.Box_Office_in_CRORE.mean()

# %%
rate_mean = df.Rating.mean()

# %%
df.fillna(rate_mean)

# %%
df.fillna({'Rating':rate_mean})

# %%
df.fillna({'Rating':rate_mean},limit = 2)
