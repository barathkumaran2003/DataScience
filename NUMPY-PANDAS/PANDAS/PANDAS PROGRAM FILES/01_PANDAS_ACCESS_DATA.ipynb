# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('D:\PYTHON CODINGS\PANDAS\STACK OVERFLOW SURVEY SET\stack-overflow-developer-survey-2019\survey_results_public.csv')
schema = pd.read_csv('D:\PYTHON CODINGS\PANDAS\STACK OVERFLOW SURVEY SET\stack-overflow-developer-survey-2019\survey_results_schema.csv')

# %%
pd.set_option('display.max_columns',85)

# %%
df

# %%
df['Country']

# %%
type(df['LanguageWorkedWith'])

# %%
df.loc[0]

# %%
df.loc[0,'MainBranch']

# %%
df.loc[[0,1,2],['MainBranch','Hobbyist']]

# %%
df.loc[0:8,'Respondent':'OpenSource']

# %%
schema.sample(2)

# %%
schema.QuestionText

# %%
df[['Sexuality','Country']]

# %%
df.iloc[0,1]

# %%
df.iloc[0,0]

# %%
df.iloc[0:9,1:5]

# %%
df.iloc[[1,3,4,5],[2,3,4,8,9,11]]

# %%
schema.loc[4]

# %%
schema.loc[4,'QuestionText']
