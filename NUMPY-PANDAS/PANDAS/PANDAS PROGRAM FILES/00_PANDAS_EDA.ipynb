# %%
import pandas

# %%
pandas.__version__

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('D:\PYTHON CODINGS\PANDAS\STACK OVERFLOW SURVEY SET\stack-overflow-developer-survey-2019\survey_results_public.csv')

# %%
df.head() # pass numeric parameters to get limited records

# %%
df.tail() # pass numeric paramter

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df['Sexuality'].value_counts()

# %%
df['Sexuality'].unique()

# %%
dt = pd.read_csv('D:\PYTHON CODINGS\PANDAS\STACK OVERFLOW SURVEY SET\stack-overflow-developer-survey-2019\survey_results_public.csv')

# %%
pd.set_option('display.max_columns',85)

# %%
dt

# %%
schema = pd.read_csv('D:\PYTHON CODINGS\PANDAS\STACK OVERFLOW SURVEY SET\stack-overflow-developer-survey-2019\survey_results_schema.csv')

# %%
pd.set_option('display.max_rows',85)

# %%
schema

# %%
dt.head(3)
