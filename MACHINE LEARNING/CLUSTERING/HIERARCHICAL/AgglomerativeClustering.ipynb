# %% [markdown]
# initially every datapoints iteself a cluster
# 5 -> 4 -> 3 -> 2 -> 1
# until all points belong to one cluster

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
df = pd.read_csv('./AGGLOMERATIVE.csv')

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data = df.iloc[:, 2:5]

# %%
data
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
plt.scatter(data.Age,data['Annual Income (k$)'])

# %%
# AS WE CANT MAKE INDIVIDUAL CLUSTER FOR THESE DATA WE USE DENDROGRAM

# %%
dendrogram = sch.dendrogram(sch.linkage(data,method = 'ward')) # linkage technique
plt.xlabel('customers')
plt.ylabel('euclidean')
# Out:
# Text(0, 0.5, 'euclidean')

# %%
cluster = AgglomerativeClustering(n_clusters = )

# %%
y_pred = cluster.fit_predict(data)

# %%
y_pred
# Out:
# array([49, 48, 51, 48, 33, 48, 25, 67, 16,  5, 16, 60, 16, 48, 25, 48, 33,
#         5,  9, 60, 33,  5,  4,  5,  4, 32,  9, 61,  9, 32, 63, 17, 63, 62,
#         4, 17, 10, 17, 10, 17, 50, 62, 39, 14, 39, 14, 66, 65, 65, 65, 66,
#        14, 13, 20, 45, 45, 66, 21, 13, 45, 21, 34, 21, 20, 43, 34,  2, 21,
#        34, 13, 21, 45, 43, 43, 43, 29,  2,  2, 29,  2, 43, 27,  0,  2, 29,
#         2, 18, 29, 27, 11, 52, 59, 11, 31, 31, 44, 11, 44, 11, 24, 59, 11,
#        52, 44, 18, 59,  0, 11,  0,  0,  0, 24, 31, 24, 24, 24,  0, 18, 11,
#        18, 44, 31, 64, 23, 54, 26, 58, 23, 40, 26, 57, 26, 54, 26, 22, 15,
#        57, 26, 22, 26, 40, 15, 54, 15, 22, 15, 58, 26, 36, 15, 37, 23, 37,
#         7, 37, 15, 35,  7, 35, 26,  8,  7, 22, 15,  8,  7, 36, 19, 36,  6,
#        53,  6, 53, 19, 28, 19, 28,  6, 28, 12, 30, 12,  1, 12, 30, 12, 56,
#        42,  1, 12,  1, 42, 38, 46,  3, 47,  3, 47, 41, 55], dtype=int64)

# %%
plt.scatter(data['Age'],data['Annual Income (k$)'],c=cluster.labels_,cmap = 'rainbow')

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(data,y_pred)

# %% [markdown]
# i) each individual itself a cluster
# 1,2      3,4   5 -  5 cluster
# (1,2)   3,4    5 - 4 cluster
# (1,2)   (3,4)   5 - 3 cluster
# (1,2)    ((3,4), 5) - 2 cluster
# ((1,2),((3,4),5)) - 1 cluster
