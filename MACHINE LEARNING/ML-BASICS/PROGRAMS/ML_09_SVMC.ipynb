# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clrs
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA

# %%
# !pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df = pd.read_excel('MACHINE LEARNING/ML_00_PROGRAM FILES/DATASETS/UCI DEFAULT CREDIT CARD/default of credit card clients.xls',header = 1)

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.rename(columns = {'default payment next month':'Default_pay'},inplace = True)

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'Default_pay'],
#       dtype='object')

# %%
df.drop('ID',axis = 1,inplace = True)

# %%
df
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
# ...

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL      0
# SEX            0
# EDUCATION      0
# MARRIAGE       0
# AGE            0
# PAY_0          0
# PAY_2          0
# PAY_3          0
# PAY_4          0
# PAY_5          0
# PAY_6          0
# BILL_AMT1      0
# BILL_AMT2      0
# BILL_AMT3      0
# BILL_AMT4      0
# BILL_AMT5      0
# BILL_AMT6      0
# PAY_AMT1       0
# PAY_AMT2       0
# PAY_AMT3       0
# PAY_AMT4       0
# PAY_AMT5       0
# PAY_AMT6       0
# Default_pay    0
# dtype: int64

# %%
df.dtypes
# Out:
# LIMIT_BAL      int64
# SEX            int64
# EDUCATION      int64
# MARRIAGE       int64
# AGE            int64
# PAY_0          int64
# PAY_2          int64
# PAY_3          int64
# PAY_4          int64
# PAY_5          int64
# PAY_6          int64
# BILL_AMT1      int64
# BILL_AMT2      int64
# BILL_AMT3      int64
# BILL_AMT4      int64
# BILL_AMT5      int64
# BILL_AMT6      int64
# PAY_AMT1       int64
# PAY_AMT2       int64
# PAY_AMT3       int64
# PAY_AMT4       int64
# PAY_AMT5       int64
# PAY_AMT6       int64
# Default_pay    int64
# dtype: object

# %% [markdown]
# [Dataset reference page](https://archive.ics.uci.edu/dataset/350/default+of+credit+card+clients)

# %%
df.SEX.unique() #(1 = male; 2 = female).
# Out:
# array([2, 1], dtype=int64)

# %%
df.EDUCATION.unique() #(1 = graduate school; 2 = university; 3 = high school; 4 = others)
# But we also have 0,5,6 here
# Out:
# array([2, 1, 3, 5, 4, 6, 0], dtype=int64)

# %%
#(1 = married; 2 = single; 3 = others).
df.MARRIAGE.unique()
# Having 0 here
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
# Considering 0 as missing values

# %%
df[(df.MARRIAGE == 0) | (df.EDUCATION ==0)]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 218       110000    2          3         0   31      0      0      0      0
# 809       160000    2          2         0   37      0      0      0      0
# 820       200000    2          3         0   51     -1     -1     -1     -1
# 1019      180000    2          3         0   45     -1     -1     -2     -2
# 1443      200000    1          3         0   51     -1     -1     -1     -1
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 28602     200000    2          3         0   37      1     -1     -1     -1
# 28603     110000    2          3         0   44      2      2      2      2
# 28766      80000    2          3         0   40      2      2      3      2
# 29078     100000    2          3         0   56      1      2      0      0
# 29111     300000    2          3         0   53     -2     -2     -2     -2
#
# ...

# %%
df1 = df[(df.MARRIAGE != 0) & (df.EDUCATION !=0)]

# %%
df1.shape
# Out:
# (29932, 24)

# %%
df1.EDUCATION.unique()
# Out:
# array([2, 1, 3, 5, 4, 6], dtype=int64)

# %%
df1.MARRIAGE.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %% [markdown]
# ### DOWNSAMPLING

# %%
df_no_default = df1[df1.Default_pay == 0]
df_no_default.shape
# Out:
# (23301, 24)

# %%
df_default = df1[df1.Default_pay == 1]
df_default.shape
# Out:
# (6631, 24)

# %%
df_no_default_ds = resample(df_no_default,replace = False,n_samples = 1000,random_state = 42)

# %%
df_default_ds = resample(df_default,replace = False,n_samples = 1000,random_state = 42)

# %%
df_no_default_ds.shape
# Out:
# (1000, 24)

# %%
df_default_ds.shape
# Out:
# (1000, 24)

# %%
df2 = pd.concat([df_no_default_ds,df_default_ds])

# %%
df2
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 641       130000    2          3         1   28      0      0      0      0
# 4678      170000    1          3         1   29      0      0      0      0
# 16004     180000    2          2         1   29      0      0      0      0
# 22974     210000    2          2         2   32     -2     -2     -2     -2
# 17535     190000    2          3         1   45      0      0      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 6154       30000    2          1         2   34      1      2      2      2
# 14072     320000    1          1         1   43     -1      0      0      0
# 5387       50000    1          2         2   23     -1     -1      0      0
# 23192     150000    2          3         1   43      0      0      0      0
# 8180      140000    1          2         1   28      0      0      0      0
#
# ...

# %%
x = df2.drop('Default_pay',axis = 1)
x
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 641       130000    2          3         1   28      0      0      0      0
# 4678      170000    1          3         1   29      0      0      0      0
# 16004     180000    2          2         1   29      0      0      0      0
# 22974     210000    2          2         2   32     -2     -2     -2     -2
# 17535     190000    2          3         1   45      0      0      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 6154       30000    2          1         2   34      1      2      2      2
# 14072     320000    1          1         1   43     -1      0      0      0
# 5387       50000    1          2         2   23     -1     -1      0      0
# 23192     150000    2          3         1   43      0      0      0      0
# 8180      140000    1          2         1   28      0      0      0      0
#
# ...

# %%
y = df2.Default_pay

# %%
x.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
#       dtype='object')

# %%
x_enc = pd.get_dummies(x,columns = ['SEX', 'EDUCATION', 'MARRIAGE', 'PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']).astype(int)

# %%
x_enc.head()
# Out:
#        LIMIT_BAL  AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 641       130000   28     100143      50456      50000          0          0
# 4678      170000   29     165027     168990     172307      35234      32869
# 16004     180000   29      25781      26000      26310      26662      26166
# 22974     210000   32        355        975        410          0          0
# 17535     190000   45      76433      78472      80548      81778      83082
#
#        BILL_AMT6  PAY_AMT1  PAY_AMT2  ...  PAY_5_7  PAY_6_-2  PAY_6_-1  \
# 641            0      2500      1000  ...        0         1         0
# 4678       33862      7200      7500  ...        0         0         0
# 16004      26176      1800      1800  ...        0         0         0
# 22974          0       979       412  ...        0         1         0
# 17535      84811      3300      3331  ...        0         0         0
#
#        PAY_6_0  PAY_6_2  PAY_6_3  PAY_6_4  PAY_6_5  PAY_6_6  PAY_6_7
# ...

# %% [markdown]
# ### SPLIT TRAIN AND TEST

# %%
x_train,x_test,y_train,y_test = train_test_split(x_enc,y,random_state = 42)

# %%
print(x_train.shape,'|',x_test.shape)
# Out:
# (1500, 81) | (500, 81)

# %%
x_train_scale = scale(x_train)
x_test_scale = scale(x_test)

# %%
x_train_scale
# Out:
# array([[ 1.06764453,  0.66459398, -0.69871481, ...,  0.        ,
#         -0.0365392 , -0.05170877],
#        [ 0.11806446, -0.8151    ,  0.04305464, ...,  0.        ,
#         -0.0365392 , -0.05170877],
#        [-0.51498893, -0.92079242, -0.36636674, ...,  0.        ,
#         -0.0365392 , -0.05170877],
#        ...,
#        [ 1.22590788, -0.39233029,  3.60225397, ...,  0.        ,
#         -0.0365392 , -0.05170877],
#        [-0.27759391,  1.61582582, -0.69871481, ...,  0.        ,
#         -0.0365392 , -0.05170877],
#        [-1.06891064, -1.34356213, -0.47601594, ...,  0.        ,
#         -0.0365392 , -0.05170877]])

# %% [markdown]
# ### SVC

# %%
clf_svm = SVC(random_state = 42)
clf_svm.fit(x_train_scale,y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred = clf_svm.predict(x_test_scale)

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot = True)
# Out:
# <Axes: >

# %%
model = SVC(random_state = 42,C = 10,gamma = 0.001,kernel = 'rbf')
model.fit(x_train_scale,y_train)
# Out:
# SVC(C=10, gamma=0.001, random_state=42)

# %%
y_pred1 = model.predict(x_test_scale)

# %%
cm = confusion_matrix(y_test,y_pred1)

# %%
sns.heatmap(cm,annot = True)
# Out:
# <Axes: >
